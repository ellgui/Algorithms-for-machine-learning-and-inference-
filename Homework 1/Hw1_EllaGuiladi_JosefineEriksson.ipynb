# %% [markdown]
# $\qquad$ $\qquad$$\qquad$ **TDA 231 Machine Learning: Homework 1** <br />
# $\qquad$ $\qquad$$\qquad$ **Goal: Introduction to Probability,  MLE and Jupyter python Notebook**<br />
# $\qquad$ $\qquad$$\qquad$                   **Grader: Emilio** <br />
# $\qquad$ $\qquad$$\qquad$                   **Submitted by:
# Ella Guiladi, 930509-0822, guiladi@student.chalmers.se and Josefine Eriksson, 961207-0962, joseerik@student.chalmers.se** <br />

# %% [markdown]
# General guidelines:
# * All solutions to theoretical and pratical problems must be submitted in this ipynb notebook, and equations wherever required, should be formatted using LaTeX math-mode.
# * All discussion regarding practical problems, along with solutions and plots should be specified in this notebook.
# All plots/results should be visible such that the notebook do not have to be run. But the code in the notebook should reproduce the plots/results if we choose to do so.
# * Your name, personal number and email address should be specified above.
# * All tables and other additional information should be included in this notebook.
# * ** Before submitting, make sure that your code can run on another computer. That all plots can show on another computer including all your writing. It is good to check if your code can run here: https://colab.research.google.com **
# * ** Upload both the .ipynb and the generatable .html file (that can be exported through File > Download As > HTML) **

# %% [markdown]
# **Jupyter/IPython Notebook** is a collaborative Python web-based environment. This will be used in all our Homework Assignments. It is installed in the halls ES61-ES62, E-studio and MT9. You can also use google-colab: https://colab.research.google.com
# to run these notebooks without having to download, install, or do anything on your own computer other than a browser.
# Some useful resources:
# 1. https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/ (Quick-start guide)
# 2. https://www.kdnuggets.com/2016/04/top-10-ipython-nb-tutorials.html
# 3. http://data-blog.udacity.com/posts/2016/10/latex-primer/ (latex-primer)
# 4. http://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html (markdown)

# %% [markdown]
# # Theoretical problems
#
# ## [Bayes Rule, 3 points]
#
# After your yearly checkup, the doctor has bad news and good news. The
# bad news is that you tested positive for a very serious cancer and
# that the test is 99.2% accurate i.e. the probability of testing
# positive given you have the disease is 0.992. The probability of
# testing negative if you don’t have the disease is the same (also 0.992). The good news is that it is a rare condition affecting only 1 in 1,000 people. What is the probability you actually have the disease?
#
# After doing all your calculations you realize that there was a misprint on the test, and the accuracy was actually only 92% (for both testing postive given that you have the disease and for testing negative given that you do not have the disease). How will this change your probability of having the disease?
#
# (Show all calculations and the final result.)

# %% [markdown]
# ## [Setting hyperparameters, 2 points]
#
# Suppose $\theta$ is a random variable generated from a beta distribution as: $\theta \sim \mbox{Beta}(a^2,b)$. Also assume that  the expectation of $\theta$ is $m$: $E[\theta] = m$
# and the variance of $\theta$ is v: $\mbox{var}(\theta) = v$. Express $a$ and $b$ in term of (only) $m$ and $v$.
# For more information about the $\mbox{Beta}$ distribution see https://en.wikipedia.org/wiki/Beta_distribution.

# %% [markdown]
# ## [Correlation and Independence, 2 points]
#
# Let $X$ be a continuous random variable, uniformly distributed in $[-2, +2]$ and let $Y := X^4$. Clearly $Y$ is not independent of $X$ -- in fact it is uniquely determined by $X$. However, show that the covariance of $X$ and $Y$ is 0: $\mbox{cov}(X, Y ) = 0$.
# Show and justify every step of the proof. Statements like "it is obvious that, it is trivial ..." will not be accepted.

# %% [markdown]
# Write Answers  here. Double-click (or enter) to edit. Latex mathematical expressions can just be written by starting with "$" and ending with the same character.
#
# ## Bayes Rules
#
# a) Use Bayes Rule wich is defined as:\
# $P(B|A)=\frac{P(A | B) \cdot P(B)}{P(A)}$
#
# where\
# P(A|B) = The chance of testing positive given that you have cancer = 0.992\
# P(B|A) = The chance of having cancer testing positive\
# P(A) = The chance of testing positive\
# P(B) = The chance of having cancer = 1/1000 = 0.0001
#
# We are looking for $P(B|A)$, where everything in the equation above is known except  𝑃(𝐴) , which can be found by the following equation,
# $P(A)=P(A|B)\cdot P(B)+P(A|B')\cdot P(B')=0.992⋅0.0001+(1-0.992)⋅(1-0.0001)=0.0081.$
#
# This result in $P(B|A)=0.0122$, i.e 1,22\% that you have the disease.
#
# b) If the chance of testing positive given that you have cancer is instead 0.92, i.e $P(A|B)=0.92$, then  $P(A)=0.08$, by using the same procedure as above.
#
# This results in $P(B|A)=0.00149$, i.e 0.15\% that you have the disease instead.
#
# ## Setting hyperparameters
# A beta distribution, $Beta(\alpha,\beta)$, with shape parameters $\alpha$ and $\beta$ has the expected value given by $$E[\theta]= \frac{\alpha}{\alpha+\beta}$$ and the variance given by $$Var[\theta]=\frac{\alpha \beta}{(\alpha+\beta)^{2}(\alpha + \beta +1)}.$$
#
#
# Given that $\theta \sim Beta(a^{2},b)$ it follows that the shape parameters $\alpha$ and $\beta$ equals $\alpha=a^{2}$ and $\beta=b$. Inserting $\alpha=a^{2}$ and $\beta=b$, and the given expected value and variance one obtains $$E[\theta]=\frac{a^{2}}{a^{2}+b}=m$$ and $$Var[\theta]=\frac{a^{2} b}{(a^{2}+b)^{2}(a +b +1)}=\nu.$$ From the equation for the expected value it follows that $$b=a^{2}(\frac{1}{m}-1).$$ In the same way, the expression for $a$ can be obtained from the expression for the variance with the obtained expression for b inserted as  $$\frac{a^{2}(a^{2}(\frac{1}{m}-1))}{(a^{2}+(a^{2}(\frac{1}{m}-1))^{2}(a^{2}+a^{2}(\frac{1}{m}-1)+1)}=\nu,$$ which one can simplify and obtain $$a=\sqrt{m(\frac{m-m^{2}}{v}-1)}.$$ Inserting the obtained expression for $a$ in the expression for $b$ one obtains $$b=m(\frac{m-m^{2}}{\nu}-1)(\frac{1}{m}-1)$$
#
#
# ## Correlation
# Since $X$ is a continuous random variable, uniformly distributed in $[-2, +2]$, the formula for the expected value is,
#
# $E[X]=\int_a^b xf(x)dx$.
#
# Since $X$ is uniformly distributed in $[-2, +2]$, the probability distribution function $f(x)$ can be written as,
#
# $f(x)=\frac{1}{b-a}=\frac{1}{2-(-2)}=\frac{1}{4}.$
#
# The expected value can then be calculated as,
#
# $E[X]=\int_2^{-2} x\frac{1}{4}dx=0$, for a continous random variable that is uniformly distributed.
#
# The formula for the covariance is,
#
# $cov(X,Y)=E[(X-E[X])(Y-E[Y])]$,
#
# and can be rewritten as,
#
# $cov(X,Y) = E[(X-E[X])(Y-E[Y])] = E[XY-XE[Y]-E[X]Y+E[X]E[Y]]$.
#
# Since $E[E[X]]=E[X]$ expression can bli simplified as,
#
# $E[XY-XE[Y]-E[X]Y+E[X]E[Y]] = E[XY] - E[X]E[Y]- E[X]E[Y]+E[X]E[Y] = E[XY]-E[X]E[Y]$.
#
# We also know that $Y=X^4$, which can simplify the equation further as,
#
# $E[XY]-E[X]E[Y] = E[X\cdot X^4]-E[X]E[X^4] = E[X^5]-E[X]E[X^4]$,
#
# where $E[X^5]=\int_2^{-2} x^5\frac{1}{4}dx=0$ and $E[X]=0$, resulting in the final expression,
#
# $cov(X,X^4)= E[X^5]-E[X]E[X^4]=0-0\cdot E[X^4]=0$

# %% [markdown]
# # Practical problems
#
# **Useful python libraries/functions:**
# * **General:**  shape, reshape, np.mean etc.
# * **Plotting:** plot, scatter, legend, hold, imshow, subplot, grid, title etc. Always show legends for your plots.
# * **Code:**  Make sure your code is well commented and variables have intuitive names. Organize your code into functions and comment on the input and output.
#
# ## [Spherical Gaussian estimation, 9 points]
#
# Consider a dataset $X$ consisting of i.i.d. observations
# generated from a spherical Gaussian distribution $N(\mu, 2\sigma^2I)$, where $\mu \in \mathbb{R}^p$, $I$
# is the $p \times p $ identity matrix, and $\sigma^2$ is a scalar.
#
# (a) Write the mathematical expression for the Maximum Likelihood Estimator (MLE) for $\mu$ and $\sigma$ in above setup. (HINT: Use latex equations here).
#
# (b) Implement a function **sge(X)** that estimates the mean $\mu$ and the standard deviation $\sigma$ from the given data $X$, using exactly the mathematical expression derived in (a). Note: You cannot use **numpy.cov**, **numpy.mean**, **numpy.sum** or any other library functions for calculating the mean, variance, standard deviation. (Hint: A skeleton of this function **sge(X)** is provided in the code from the next cell).
#
# (c) Implement a function **myplot1(X)** which takes as input the dataset $X$; and draws, on the same plot, the following:
# 1. A scatter plot of the original data $X$,
# 2. Circles with center $\mu$ and radius $r= \sqrt{2}k\sigma$ for $k=1, 2, 3$ where $\mathbf{\mu}$ and $\sigma$ denotes the mean and standard deviation estimated using **sge(X)**.
# 3. Legend for each circle indicating the fraction of points (in the original dataset) that lie outside the circle boundary.
#
# (d) Load the dataset from http://bit.ly/HW1_2019 and run your code using only the first two features of the dataset. Submit the resulting plot as well as your implementation here.
#
# For more information about the spherical Gaussian distribution, see https://en.wikipedia.org/wiki/Multivariate_normal_distribution.
# For more information about the identity matrix see: https://en.wikipedia.org/wiki/Identity_matrix

# %% [markdown]
# Double-click (or enter) to edit. Write Answer to (a) here. Latex mathematical expressions can just be written by starting with "$" and ending with the same character.
#
# We have $ \mathcal{N}(\mathbf{X} | \mu, \Sigma)$, where the covariance matrix $\Sigma=\operatorname{diag}\left(\sigma_{1}^{2}, \sigma_{2}^{2}, \ldots, \sigma_{n}^{2}\right)$.
#
# In our case $N(\mu, 2\sigma^2I)$, i.e $\Sigma=2\sigma^2I$.
#
# In order to find the maximum likelihood, one needs to find $\mu$ and $\Sigma$ that maximises the following expression,
#
# $L(X | \mu, \Sigma)=\prod_{n=1}^{N}p(x_n ; \mu, \Sigma)$.
#
# The multivariate Gaussian distribution becomes,
#
# $p\left(\mathbf{x}_{n} | \sigma^{2}, \mu\right)=\Pi_{n=1}^{N}\left(\frac{1}{(2 \pi)^{1 / 2} \mid 2 \sigma^{2} \mid^{1/2}}\right) \exp \left(-\frac{1}{4 \sigma^{2}}\left(\mathbf{x}_{n}-\mu\right)^{T}\left(\mathbf{x}_{n}-\mu\right)\right)$.
#
# To simplify the calculation, it is possible to take the logarithm of the likelihood function.
#
# $\log(L)=\sum_{n=1}^{N}\left(-\frac{1}{2} \log (2 \pi)-\frac{1}{2} \log \left(\mid2\sigma^{2} \mid\right)-\frac{1}{4 \sigma^{2}}\left(\mathbf{x}_{n}-\mu\right)^{T}\left(\mathbf{x}_{n}-\mu\right)\right)$.
#
# To find the maximum of the log likelihood, one takes the partial derivative of the equation with respect to $\mu$ and with respect to $\sigma$ respectively. By setting the partial derivates equal to 0 and using the partial derivative rule $\frac{\partial W^{T} A W}{\partial W}=2 A W$, the optimal value of each parameter is found, which is presented below,
#
#
# $\frac{\partial \log (L)}{\partial \boldsymbol{\mu}}=\frac{1}{4 \sigma^{2}} \sum_{n=1} 2\left(\mathbf{x}_{n}-\hat{\boldsymbol{\mu}}\right)=N \hat{\boldsymbol{\mu}}-\sum_{n=1}^{N} \mathbf{x}_{n}=0$,
#
# resulting in the following expresssion,
#
#
# $\begin{aligned} \hat{\mu} &=\frac{1}{N} \sum_{n=1}^{N} \mathbf{x}_{n}\end{aligned}$.
#
# Similar calculations were done for $\sigma$,
#
# $\frac{\partial \log (L)}{\partial \sigma}=-\frac{N}{\hat{\sigma}}+\frac{1}{2 \hat\sigma^{3}} \sum_{n=1}^{N}\left(\mathbf{x}_{n}-\boldsymbol{\mu}\right)^{T}\left(\mathbf{x}_{n}-\boldsymbol{\mu}\right)=0$,
#
# and
#
# $\hat{\sigma}^{2}=\frac{1}{2 N} \sum_{n=1}^{N}\left(\mathbf{x}_{n}-\boldsymbol{\mu}\right)^{T}\left(\mathbf{x}_{n}-\boldsymbol{\mu}\right)$,
#
# resulting in,
#
# $\hat{\sigma}=\sqrt{\frac{1}{2 N} \sum_{n=1}^{N}\left(\mathbf{x}_{n}-\boldsymbol{\mu}\right)^{T}\left(\mathbf{x}_{n}-\boldsymbol{\mu}\right)}$.

# %%
# Sample Answer to (b)
import numpy as np # numpy


def sge(X):
    """
    This function computes the mean mu and standard deviation sigma 
    for a dataset coming from spherical Gaussian distribution N(mu, 2 sigma^2 I)

    @param X : A numpy array of size n x p where each row represents a p-dimensional data point
    e.g. X = [ [2, 1], [3, 7], [4 ,5] ] is a dataset with 3 samples having two coordinates each.
    @return mu: A numpy array of size p representing the estimated mean of the dataset
    @return sigma: A real number indicating the estimated standard deviation of the dataset
    """
    n=X.shape[0]
    p=X.shape[1]
    mu = 0
    
    for x_n in X:
        mu += x_n / n      
    D = X - mu
    
    sigmaSquare = 0
    for diff in D:
        sigmaSquare += diff.dot(np.transpose(diff))
        
    sigma = np.sqrt(sigmaSquare/(2*n*p))
    
    return mu, sigma

# %%
# Sample Answer to (c) and (d)
#%matplotlib inline  # Make it possible to show plots in the notebooks.
import numpy as np
import matplotlib
import matplotlib.pyplot as plt # for plots

# Sample code
def myplot1(X):
    """
    This function plots a scatter plot of the original data as well as circles with center 𝜇 and radius 𝑟=√2𝑘𝜎 for k=1,2,3.
    It then calculates the fraction of datapoints outside these circles, which are visualised in the legend.
    @param X : A numpy array of size n x p where each row represents a p-dimensional data point
    """
    mu, sigma = sge(X)
    plt.figure(figsize=(10,10))
    
    #A scatter plot of the original data X
    plt.scatter(X[:,0], X[:,1], alpha=0.4) #plotting the two first features
    
    legend = []
    
    #plot circles and calculate fraction of datapoints outside them
    for k in range(1,4):
        #Circles with center 𝜇 and radius 𝑟=√2𝑘𝜎 for 𝑘=1,2,3  
        theta = np.linspace(0,2*np.pi,100)
        r = np.sqrt(2)*k*sigma
        
        x=mu[0] + r*np.cos(theta)
        y=mu[1] + r*np.sin(theta)

        plt.plot(x, y)
        distanceOutliers = np.sum(np.linalg.norm(X-mu,axis=1) > r) / len(X[:,1]) #To calculate Euclidean distance 
        
        #Legend for each circle indicating the fraction of points that lie outside the circle boundary.
        legend.append("Fraction of points outside the circle boundary: %.4f" % (distanceOutliers))
    
    legend.append("The original dataset")
    plt.legend(legend)
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title('Original data with circles of mean mu and radius r')
    plt.axis('equal')
    

# Load the dataset
dataset_source = np.DataSource().open('http://bit.ly/HW1_2019')
X = np.loadtxt(dataset_source)[:,:2]
# Plot. TODO Make sure to only plot the first two features.
myplot1(X)
